# %% [markdown]
# # Example: Using the app in a Jupyter notebook
#
# This notebook demonstrates loading the project package and using its API.
# Ensure the project is installed in editable mode and the uv virtualenv is selected as the Jupyter kernel (see [Jupyter how-to](../docs/how-to/jupyter.md)).

# %%
import sys

from app import __version__

print(f"App version: {__version__}")
print(f"Python: {sys.version}")
# Out:
# Running cells with '.venv (Python 3.13.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/ivannedjalkov/Projects/template-uv/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
from app.cli import AppCli

cli = AppCli()
greeting = cli.hello(name="notebook", log_level="info")
print(greeting)

# %%
version_str = cli.version()
print(f"Version from CLI: {version_str}")
